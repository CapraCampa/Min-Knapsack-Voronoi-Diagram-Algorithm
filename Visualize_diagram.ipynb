# %%
import numpy as np
# I still have to pip install plt...
import matplotlib.pyplot as plt

# %%
# Idea: Import minKnapsack function from the c++ code!
voronoi_diagram = minKnapsack()

plt.plot()
plt.show()
